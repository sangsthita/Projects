# %% [markdown]
# # Skin_Cancer_Detection using CNN

# %% [markdown]
# ## The dataset consists of 10015 dermatoscopic images which can serve as a training set for academic machine learning purposes. The objective to build deep learning model to classify given query image into one of the 7 different classes of skin cancer.

# %% [markdown]
# #### Sourses:
# Data: https://www.kaggle.com/kmader/skin-cancer-mnist-ham10000

# %% [markdown]
# This the HAM10000 ("Human Against Machine with 10000 training images") dataset.It consists of 10015 dermatoscopicimages which are released as a training set for academic machine learning purposes and are publiclyavailable through the ISIC archive. This benchmark dataset can be used for machine learning and for comparisons with human experts.
#
# It has 7 different classes of skin cancer which are listed below :
# 1. Melanocytic nevi
# 2. Melanoma
# 3. Benign keratosis-like lesions
# 4. Basal cell carcinoma
# 5. Actinic keratoses
# 6. Vascular lesions
# 7. Dermatofibroma
#
# Here I will try to detect 7 different classes of skin cancer using Convolution Neural Network with keras tensorflow in backend and then analyse the result to see how the model can be useful in practical scenario.
# We will move step by step process to classify 7 classes of cancer.

# %% [markdown]
# In this kernel I have followed following 14 steps for model building and evaluation which are as follows :
#
# Step 1: Importing Essential Libraries
#
# Step 2: Loading data and Making labels
#
# Step 3: Train Test Split
#
# Step 4: Exploratory data analysis (EDA)
#
# Step 5: Model Building (CNN)
#
# Step 6: Setting Optimizer & Annealing
#
# Step 7: Fitting the model
#
# Step 8: Model Evaluation

# %% [markdown]
# # Step 1: Importing Essential Libraries

# %%
import pandas as pd
import numpy as np
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# # Step 2: Loading data and Making labels

# %%
df = pd.read_csv("hmnist_28_28_RGB.csv")

# %%
df.tail()
# Out:
#        pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005  \
# 10010        183        165        181        182        165        180
# 10011          2          3          1         38         33         32
# 10012        132        118        118        167        149        149
# 10013        160        124        146        164        131        152
# 10014        175        142        121        181        150        134
#
#        pixel0006  pixel0007  pixel0008  pixel0009  ...  pixel2343  pixel2344  \
# 10010        184        166        182        188  ...        208        185
# 10011        121        104        103        132  ...         96         79
# 10012        175        156        160        184  ...        204        181
# 10013        167        127        146        169  ...        185        162
# 10014        181        150        133        178  ...        159         79
#
#        pixel2345  pixel2346  pixel2347  pixel2348  pixel2349  pixel2350  \
# 10010        187        208        186        186        206        187
# 10011         76         24         23         21          3          4
# 10012        178        181        159        153        172        151
# 10013        167        184        157        166        185        162
# 10014         82        174        137        125        175        139
#
#        pixel2351  label
# 10010        189      0
# 10011          1      0
# 10012        145      0
# 10013        172      0
# 10014        126      6
#
# [5 rows x 2353 columns]

# %% [markdown]
# # Step 3: Train Test Split

# %%
fractions=np.array([0.8,0.2])

df=df.sample(frac=1)

train_set, test_set = np.array_split(df, (fractions[:-1].cumsum() * len(df)).astype(int))

# %%
print(len(train_set))
# Out:
# 8012

# %%
print(len(test_set))
# Out:
# 2003

# %%
df.label.unique()
# Out:
# array([4, 2, 6, 1, 0, 3, 5])

# %%
# reference: https://www.kaggle.com/kmader/skin-cancer-mnist-ham10000/discussion/183083
classes={
    0:('akiec', 'actinic keratoses and intraepithelial carcinomae'),
         
    1:('bcc' , 'basal cell carcinoma'),
         
    2:('bkl', 'benign keratosis-like lesions'),
         
    3:('df', 'dermatofibroma'),
         
    4:('nv', ' melanocytic nevi'),
         
    5:('vasc', ' pyogenic granulomas and hemorrhage'),
         
    6:('mel', 'melanoma'),
}

# %%
y_train=train_set['label']

x_train=train_set.drop(columns=['label'])

y_test=test_set['label']

x_test=test_set.drop(columns=['label'])

columns=list(x_train)

# %%
import torch

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

print(device)
# Out:
# cpu

# %% [markdown]
# # Step 4: Exploratory Data Analysis and Preprocessing

# %%
sns.set_style("whitegrid") 
plt.figure(figsize=(10, 6)) 


sns.countplot(x=train_set['label'], palette="viridis")  


plt.title("Distribution of Labels in the Dataset", fontsize=16, weight='bold')
plt.xlabel("Labels", fontsize=14)
plt.ylabel("Count", fontsize=14)

plt.show()

# %%
from imblearn.over_sampling import RandomOverSampler 

oversample = RandomOverSampler()

x_train,y_train  = oversample.fit_resample(x_train,y_train)

# %%
sns.set_style("whitegrid") 
plt.figure(figsize=(10, 6)) 


sns.countplot(x=y_train, palette="viridis")  


plt.title("Distribution of Labels in the Dataset", fontsize=16, weight='bold')
plt.xlabel("Labels", fontsize=14)
plt.ylabel("Count", fontsize=14)

plt.show()

# %%
import matplotlib.pyplot as plt
import random

num=random.randint(0,8000)
x_train=np.array(x_train, dtype=np.uint8).reshape(-1,28,28,3)

plt.imshow(x_train[num].reshape(28,28,3))
plt.title("Random image from training data")
plt.show()
num=random.randint(0,8000)
plt.imshow(x_train[num].reshape(28,28,3))
plt.title("Random image from training data")
plt.show()

num=random.randint(0,8000)
plt.imshow(x_train[num].reshape(28,28,3))
plt.title("Random image from training data")
plt.show()

# %% [markdown]
# # Step 5: Model Building (CNN)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Flatten, Dense, MaxPool2D
import tensorflow as tf

# %%
#https://keras.io/api/models/sequential/
#https://keras.io/api/layers/core_layers/dense/
#https://keras.io/api/layers/merging_layers/add/
#https://keras.io/api/layers/convolution_layers/convolution2d
#https://keras.io/api/layers/convolution_layers/convolution2d
#https://www.tensorflow.org/api_docs/python/tf/keras/layers/BatchNormalization


# %time 

model = Sequential()

model.add(Conv2D(16, 
                 kernel_size = (3,3), 
                 input_shape = (28, 28, 3), 
                 activation = 'relu', 
                 padding = 'same'))

model.add(MaxPool2D(pool_size = (2,2)))
model.add(tf.keras.layers.BatchNormalization())

model.add(Conv2D(32, 
                 kernel_size = (3,3), 
                 activation = 'relu'))

model.add(Conv2D(64, 
                 kernel_size = (3,3), 
                 activation = 'relu'))

model.add(MaxPool2D(pool_size = (2,2)))

model.add(tf.keras.layers.BatchNormalization())

model.add(Conv2D(128, 
                 kernel_size = (3,3), 
                 activation = 'relu'))

model.add(Conv2D(256, 
                 kernel_size = (3,3), 
                 activation = 'relu'))

model.add(Flatten())
model.add(tf.keras.layers.Dropout(0.2))
model.add(Dense(256,activation='relu'))

model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Dropout(0.2))
model.add(Dense(128,activation='relu'))

model.add(tf.keras.layers.BatchNormalization())
model.add(Dense(64,activation='relu'))

model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Dropout(0.2))
model.add(Dense(32,activation='relu'))

model.add(tf.keras.layers.BatchNormalization())
model.add(Dense(7,activation='softmax'))

model.summary()
# Out:
# CPU times: user 3 μs, sys: 2 μs, total: 5 μs
# Wall time: 15.7 μs
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_5 (Conv2D)               │ (None, 28, 28, 16)     │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 14, 14, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 14, 14, 16)     │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 12, 12, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 10, 10, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 5, 5, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 3, 3, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 1, 1, 256)      │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_9           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_10          │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_11          │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 7)              │           231 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 504,103 (1.92 MB)
#  Trainable params: 502,983 (1.92 MB)
#  Non-trainable params: 1,120 (4.38 KB)

# %% [markdown]
# # Step 6: Setting Optimizer & Annealing
#
# ---

# %%
callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='best_model.keras',
    monitor='val_acc', 
    mode='max',
    verbose=1,
    save_best_only=True
)

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

model.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=optimizer,
    metrics=['accuracy']
)

# %% [markdown]
# # Step 7: Fitting the model

# %%
from datetime import datetime

start_time = datetime.now()

history = model.fit(x_train,
                    y_train,
                    validation_split=0.2,
                    batch_size = 128,
                    epochs = 50,
                    shuffle=True,
                    callbacks=[callback])

end_time = datetime.now()

print('Duration: {}'.format(end_time - start_time))
# Out:
# Epoch 1/50
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 7s 23ms/step - accuracy: 0.4133 - loss: 1.6435 - val_accuracy: 0.0280 - val_loss: 2.3427
# Epoch 2/50
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.7757 - loss: 0.6666 - val_accuracy: 0.3632 - val_loss: 1.9463
# Epoch 3/50
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.8765 - loss: 0.3593 - val_accuracy: 0.4262 - val_loss: 1.7029
# Epoch 4/50
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.9187 - loss: 0.2335 - val_accuracy: 0.4553 - val_loss: 1.5220
# Epoch 5/50
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.8786 - loss: 0.3615 - val_accuracy: 0.4856 - val_loss: 1.4055
# Epoch 6/50
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.9408 - loss: 0.1724 - val_accuracy: 0.6791 - val_loss: 0.7651
# Epoch 7/50
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.9050 - loss: 0.2965 - val_accuracy: 0.6273 - val_loss: 0.8228
# Epoch 8/50
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.9257 - loss: 0.2248 - val_accuracy: 0.6028 - val_loss: 0.9313
# Epoch 9/50
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9505 - loss: 0.1498 - val_accuracy: 0.6709 - val_loss: 0.7543
# Epoch 10/50
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.9443 - loss: 0.1686 - val_accuracy: 0.5278 - val_loss: 1.2008
# Epoch 11/50
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.9601 - loss: 0.1209 - val_accuracy: 0.9139 - val_loss: 0.2129
# Epoch 12/50
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9706 - loss: 0.0846 - val_accuracy: 0.8067 - val_loss: 0.4288
# Epoch 13/50
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.9483 - loss: 0.1547 - val_accuracy: 0.9339 - val_loss: 0.1693
# Epoch 14/50
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 6s 23ms/step - accuracy: 0.9636 - loss: 0.1138 - val_accuracy: 0.8482 - val_loss: 0.3785
# Epoch 15/50
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.9613 - loss: 0.1182 - val_accuracy: 0.8418 - val_loss: 0.3893
# Epoch 16/50
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.9864 - loss: 0.0439 - val_accuracy: 0.9075 - val_loss: 0.2642
# Epoch 17/50
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.9479 - loss: 0.1672 - val_accuracy: 0.6985 - val_loss: 0.8988
# Epoch 18/50
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.9835 - loss: 0.0479 - val_accuracy: 0.8515 - val_loss: 0.3918
# Epoch 19/50
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - accuracy: 0.9810 - loss: 0.0598 - val_accuracy: 0.6896 - val_loss: 0.9198
# Epoch 20/50
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - accuracy: 0.9718 - loss: 0.0854 - val_accuracy: 0.8784 - val_loss: 0.2983
# Epoch 21/50
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - accuracy: 0.9659 - loss: 0.1167 - val_accuracy: 0.8824 - val_loss: 0.3018
# Epoch 22/50
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - accuracy: 0.9644 - loss: 0.1119 - val_accuracy: 0.7663 - val_loss: 0.6815
# Epoch 23/50
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - accuracy: 0.9762 - loss: 0.0772 - val_accuracy: 0.9339 - val_loss: 0.1718
# Epoch 24/50
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - accuracy: 0.9892 - loss: 0.0351 - val_accuracy: 0.9281 - val_loss: 0.1911
# Epoch 25/50
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - accuracy: 0.9896 - loss: 0.0333 - val_accuracy: 0.7606 - val_loss: 1.0474
# Epoch 26/50
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - accuracy: 0.9709 - loss: 0.0886 - val_accuracy: 0.9201 - val_loss: 0.2057
# Epoch 27/50
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.9658 - loss: 0.1114 - val_accuracy: 0.9620 - val_loss: 0.0856
# Epoch 28/50
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.9925 - loss: 0.0253 - val_accuracy: 0.8814 - val_loss: 0.3584
# Epoch 29/50
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.9923 - loss: 0.0251 - val_accuracy: 0.9200 - val_loss: 0.1913
# Epoch 30/50
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.9879 - loss: 0.0364 - val_accuracy: 0.9213 - val_loss: 0.2133
# Epoch 31/50
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.9796 - loss: 0.0687 - val_accuracy: 0.9708 - val_loss: 0.0998
# Epoch 32/50
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.9923 - loss: 0.0233 - val_accuracy: 0.9301 - val_loss: 0.1729
# Epoch 33/50
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.9635 - loss: 0.1164 - val_accuracy: 0.9830 - val_loss: 0.0524
# Epoch 34/50
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - accuracy: 0.9766 - loss: 0.0764 - val_accuracy: 0.9807 - val_loss: 0.0489
# Epoch 35/50
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - accuracy: 0.9949 - loss: 0.0158 - val_accuracy: 0.9081 - val_loss: 0.2638
# Epoch 36/50
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - accuracy: 0.9962 - loss: 0.0128 - val_accuracy: 0.9087 - val_loss: 0.2825
# Epoch 37/50
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - accuracy: 0.9885 - loss: 0.0423 - val_accuracy: 0.7641 - val_loss: 0.9176
# Epoch 38/50
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - accuracy: 0.9738 - loss: 0.0924 - val_accuracy: 0.9798 - val_loss: 0.0545
# Epoch 39/50
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - accuracy: 0.9925 - loss: 0.0247 - val_accuracy: 0.6838 - val_loss: 1.3399
# Epoch 40/50
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.9865 - loss: 0.0457 - val_accuracy: 0.9766 - val_loss: 0.0664
# Epoch 41/50
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - accuracy: 0.9940 - loss: 0.0191 - val_accuracy: 0.9745 - val_loss: 0.0642
# Epoch 42/50
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - accuracy: 0.9961 - loss: 0.0127 - val_accuracy: 0.9140 - val_loss: 0.3134
# Epoch 43/50
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - accuracy: 0.9953 - loss: 0.0131 - val_accuracy: 0.8427 - val_loss: 0.6273
# Epoch 44/50
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - accuracy: 0.9776 - loss: 0.0723 - val_accuracy: 0.9930 - val_loss: 0.0279
# Epoch 45/50
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 7s 28ms/step - accuracy: 0.9923 - loss: 0.0223 - val_accuracy: 0.9225 - val_loss: 0.3108
# Epoch 46/50
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - accuracy: 0.9887 - loss: 0.0418 - val_accuracy: 0.8953 - val_loss: 0.4429
# Epoch 47/50
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.9864 - loss: 0.0484 - val_accuracy: 0.7320 - val_loss: 1.0758
# Epoch 48/50
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.9972 - loss: 0.0096 - val_accuracy: 0.9918 - val_loss: 0.0316
# Epoch 49/50
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.9990 - loss: 0.0038 - val_accuracy: 0.9416 - val_loss: 0.2038
# Epoch 50/50
# 236/236 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.9970 - loss: 0.0103 - val_accuracy: 0.9666 - val_loss: 0.1083
# Duration: 0:05:06.068925

# %% [markdown]
# # Step 8: Model Evaluation

# %%
#plot of accuracy vs epoch

plt.plot(history.history['accuracy'])

plt.plot(history.history['val_accuracy'])

plt.title('model accuracy')

plt.ylabel('accuracy')

plt.xlabel('epoch')

plt.legend(['train', 'val'], loc='upper left')

plt.show()

# %%
#plot of loss vs epoch

plt.plot(history.history['loss'])

plt.plot(history.history['val_loss'])

plt.title('model loss')

plt.ylabel('loss')

plt.xlabel('epoch')

plt.legend(['train', 'val'], loc='upper left')

plt.show()

# %%
model.load_weights('best_model.h5')

# %%
x_test=np.array(x_test).reshape(-1,28,28,3)

loss, acc = model.evaluate(x_test, y_test, verbose=2)
# Out:
# 63/63 - 0s - 4ms/step - accuracy: 0.9561 - loss: 0.2089

# %%
from sklearn.metrics import confusion_matrix

y_pred = model.predict(x_test)
y_pred = np.argmax(y_pred, axis=1)

conf_mat = confusion_matrix(y_test, y_pred)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
print(conf_mat)
# Out:
# [[  53    4    0    0    1    0    1]
#  [   0  105    1    0    1    0    0]
#  [   2    1  201    0   12    0    2]
#  [   1    0    0   26    0    0    0]
#  [   0    6   16    3 1299    0    8]
#  [   0    0    0    0    1   29    0]
#  [   0    2    8    0   18    0  202]]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(10,10)) 


ax = sns.heatmap(conf_mat, annot=True, cmap='Blues', linewidths=.9, ax=ax)

ax.set_title('Confusion Matrix with labels\n\n');

ax.set_xlabel('\nPredicted Values')

ax.set_ylabel('Actual Values ');

ax.xaxis.set_ticklabels(['0','1','2','3','4','5','6'])

ax.yaxis.set_ticklabels(['0','1','2','3','4','5','6'])

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(10,10)) 


ax = sns.heatmap(conf_mat/np.sum(conf_mat), annot=True, fmt='.2%', cmap='Blues', linewidths=.9, ax=ax)

ax.set_title('Confusion Matrix with labels\n\n');

ax.set_xlabel('\nPredicted Values')

ax.set_ylabel('Actual Values ');

ax.xaxis.set_ticklabels(['0','1','2','3','4','5','6'])

ax.yaxis.set_ticklabels(['0','1','2','3','4','5','6'])

plt.show()

# %%
#https://pillow.readthedocs.io/en/stable/

import PIL

image=PIL.Image.open('/Users/sakshizanjad/Downloads/Skin cancer detection AIML project/images (2).jpeg')

image=image.resize((28,28))

img=x_test[1]

img=np.array(image).reshape(-1,28,28,3)

result=model.predict(img)

print(result[0])

result=result.tolist()

max_prob=max(result[0])

class_ind=result[0].index(max_prob)

print(classes[class_ind])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# [2.9325363e-05 1.9417609e-03 1.7662704e-02 6.1178725e-05 9.7957462e-01
#  6.9086323e-05 6.6124246e-04]
# ('nv', ' melanocytic nevi')
